# %%
import numpy as np
import pandas as pd 
from os import listdir
from os.path import isfile, join
from scipy.stats.stats import spearmanr
from scipy.stats.stats import pearsonr
# %matplotlib inline
import matplotlib.pyplot as plt
import statsmodels.api as sm
import seaborn as sb
sb.set(style='ticks', palette='Set2')

# %%
#read all seapearl files
perNodefiles = [f for f in listdir('.') if (isfile(join('.', f)) and 'pearl' in f)]
perNodefiles.sort()
perNodefiles
# Out:
# ['pi02-seapearl.txt',
#  'pi03-seapearl.txt',
#  'pi06-seapearl.txt',
#  'pi08-seapearl.txt',
#  'pi12-seapearl.txt',
#  'pi13-seapearl.txt',
#  'pi14-seapearl.txt',
#  'pi15-seapearl.txt',
#  'pi16-seapearl.txt',
#  'pi18-seapearl.txt',
#  'pi19-seapearl.txt',
#  'pi20-seapearl.txt',
#  'pi21-seapearl.txt',
#  'pi22-seapearl.txt',
#  'pi24-seapearl.txt',
#  'pi25-seapearl.txt',
#  'pi26-seapearl.txt',
#  'pi27-seapearl.txt',
#  'pi28-seapearl.txt',
#  'pi29-seapearl.txt',
#  'pi30-seapearl.txt',
#  'pi31-seapearl.txt',
#  'pi32-seapearl.txt',
#  'pi33-seapearl.txt',
#  'pi35-seapearl.txt',
#  'pi36-seapearl.txt',
#  'pi37-seapearl.txt',
#  'pi38-seapearl.txt',
#  'pi39-seapearl.txt',
#  'pi40-seapearl.txt',
#  'pi41-seapearl.txt',
#  'pi42-seapearl.txt',
#  'pi43-seapearl.txt',
#  'pi45-seapearl.txt',
#  'pi47-seapearl.txt',
#  'pi48-seapearl.txt']

# %%
sensors =["Tamb"] #, "CPU1", "MEM1", "CPU2", "MEM2", "ATX12", "ATX5", "ATX5sb", "ATX3.3", "HDD12", "HDD5", "Tina", "Tinb","Tcpu1", "Tcpu2", "Thca", "Tmem1", "Tmem2", "Tout"]

# %%
#for each of the files, extract sensor data (=Tamb)
timeseriesdict = dict()
counter = 1
for nodeFile in [ 'pi14-seapearl.txt', 'pi08-seapearl.txt']:#perNodefiles:
    #read the file for this node
    print nodeFile
    df = pd.read_table(nodeFile, delim_whitespace=True)
    for givenSensor in sensors:       
            #create new dataframe for hashmap
            if (++counter) % 100 == 0:
                print counter
            #print "looking for :" + givenSensor
            view = df.loc[df['sensor'].isin([givenSensor])][0:160000]
            df_select = pd.DataFrame(view.values.copy(), view.index.copy(), view.columns.copy())
            #print df_select.shape
        
            #print number of data points in timeseries
            if (len(df_select['node']) == 0):
                continue
            KEY = (df_select['node'].iloc[0], df_select['sensor'].iloc[0]) #tuple
            #print nodeFile, givenSensor
            #print KEY
            
            del df_select['node']
            del df_select['sensor']
            
            #add to hashmap
            timeseriesdict[KEY] = df_select
            del df_select #only deletes the pointer to object
            #print '---------------------------'
     
    ##############################
    #the order of files printed gives label for each row from start of file
# Out:
# pi14-seapearl.txt
# pi08-seapearl.txt

# %%
import matplotlib.pyplot as plt
sb.set_context("notebook", rc={"lines.linewidth":2.5})

# %%
fig=plt.figure(figsize=(14,12))
L = timeseriesdict[('pi14', 'Tamb')]
L['time']=pd.to_datetime(L['time'], infer_datetime_format=True)
plt.ylabel('Temperature at Node 14', fontsize=16)
plt.xlabel('~Time', fontsize=16)
plt.plot(L['value'][::1000])
fig.savefig('Final - Temp at Node 14.jpg')

# %%
L = timeseriesdict[('pi14', 'Tamb')]
L['first_diff'] = L['value'] - L['value'].shift()
sum(L['first_diff'].iloc[1:])
# Out:
# -0.8000000000000007

# %%
fig=plt.figure(figsize=(14,12))
L['first_diff'] = L['value'] - L['value'].shift()
plt.ylabel('Difference in Temperatue at Node 14', fontsize=16)
plt.xlabel('~Time', fontsize=16)
plt.plot(L['first_diff'][::1000])
plt.ylim(-1,1)
fig.savefig('Final - Diff in Temperature -  Node 14.jpg')

# %%
#auto correlated
L = timeseriesdict[('pi14', 'Tamb')]
L['Lag in value'] = L['value'].shift()
ax=sb.jointplot('value', 'Lag in value', L[::500], kind='reg', size=20)
#ax.plot_joint(sns.kdeplot,cmap='Reds_d')
plt.ylabel('Temperature Shifted (past values)', fontsize=16)
plt.xlabel('Temperature (current values)', fontsize=16)
ax.savefig('Final - Value vs Lag Node 14 every 500.png')

# %%
L = timeseriesdict[('pi14', 'Tamb')]
L['first_diff'] = L['value'] - L['value'].shift()

# %%
L['Lag in diff'] = L['first_diff'].shift()
ax2=sb.jointplot('first_diff', 'Lag in diff', L[1::100], kind='reg', size=20, ylim=(-2,2), xlim=(-2,2)) #41831
plt.ylabel('Temperature Difference Shifted (past values)', fontsize=16)
plt.xlabel('Temperature Difference (current values)', fontsize=16)
ax2.savefig('Final - FirstDiff vs Lag Node 14 every 500.png')

# %%
from statsmodels.tsa.stattools import acf
from statsmodels.tsa.stattools import pacf

# %%
L = timeseriesdict[('pi14', 'Tamb')]
L['first_diff'] = L['value'] - L['value'].shift()
lag_correlations=acf(L['first_diff'].iloc[1::500])

# %%
lag_partial_correlations = pacf(L['first_diff'].iloc[1::500])

# %%
#first_diff : not significant >0.5 correlation with time prior t upto 40 steps
fig, ax = plt.subplots(figsize=(14,12))
sb.set_context("notebook", rc={"lines.linewidth":3.5})
plt.ylabel('Correlation Coefficient', fontsize=16)
plt.xlabel('Index of Past Temperature Value (upto 40)', fontsize=16)
ax.plot(lag_correlations, marker='o', linestyle='--', label='Auto Correlation')
ax.plot(lag_partial_correlations, marker='*', linestyle='--', label='Partial Auto Correlation')
ax.axes.legend(fontsize=16)
fig.savefig('Final - FirstDiff_Correlation Coefficients Node 14 every 500.png')

# %%
import statsmodels.api as sm

# %%
deco = sm.tsa.seasonal_decompose(L['first_diff'].iloc[1:].tolist())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-33-11c8b385ff8f> in <module>()
# ----> 1 deco = sm.tsa.seasonal_decompose(L['first_diff'].iloc[1:].tolist())
#
# AttributeError: 'module' object has no attribute 'seasonal_decompose'

# %%
from scipy import signal
L['third_diff'] = L['sec_diff'] - L['sec_diff'].shift()

# %%
#third diff
sb.jointplot('value', 'lag', J, kind='reg', size=5)
